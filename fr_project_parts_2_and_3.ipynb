# %% [markdown]
# # How easy is it to test the accuracy of a face recognition algorithm?
#
# ## Part 2 - templating the image files to make them ready for matching

# %%
# Import pandas to read the CSV into a dataframe
import pandas as pd
# Import the face matcher class
import face_matcher as fm
matcher = fm.FaceMatcher()
import re # for regex to reformat face locations into required format

# Reading CSV and checking first few rows
faces = pd.read_csv('./easy_faces_2015_one_face_only.csv')
faces.head(3)
# Out:
#   subject_id  image_sequence_number gender  age lighting view cropped  \
# 0       MotM                   1984      m   21        i   fr      nc
# 1       PetK                   2257      m   20        i   nf      nc
# 2       MosK                   1975      m   20        o   nf      nc
#
#   facial_emotion  year  part occlusion image_filters level_of_difficulty  \
# 0             sd  2015     1        e0            Gn                   e
# 1             no  2015     1        e0            Ps                   e
# 2             sd  2015     1        e0            Gs                   e
#
#                                           image_path          face_locations  \
# 0  ./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_...  [(171, 379, 439, 111)]
# 1  ./images/PetK_02257_m_20_i_nf_nc_no_2015_1_e0_...  [(118, 464, 341, 241)]
# 2  ./images/MosK_01975_m_20_o_nf_nc_sd_2015_1_e0_...  [(142, 489, 365, 266)]
#
#    faces_found
# 0            1
# 1            1
# 2            1

# %%
# Checking shape
faces.shape
# Out:
# (1961, 16)

# %%
# There is a need to convert format of the face location. Since we now know it is only one face. 
faces['face_locations'].replace(to_replace ='[\'\[\(]|[\)\]\']', value = '', regex = True, inplace=True)

# %%
faces.rename(columns={'face_locations':'face_location'}, inplace=True)

# %%
faces.head(3)
# Out:
#   subject_id  image_sequence_number gender  age lighting view cropped  \
# 0       MotM                   1984      m   21        i   fr      nc
# 1       PetK                   2257      m   20        i   nf      nc
# 2       MosK                   1975      m   20        o   nf      nc
#
#   facial_emotion  year  part occlusion image_filters level_of_difficulty  \
# 0             sd  2015     1        e0            Gn                   e
# 1             no  2015     1        e0            Ps                   e
# 2             sd  2015     1        e0            Gs                   e
#
#                                           image_path       face_location  \
# 0  ./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_...  171, 379, 439, 111
# 1  ./images/PetK_02257_m_20_i_nf_nc_no_2015_1_e0_...  118, 464, 341, 241
# 2  ./images/MosK_01975_m_20_o_nf_nc_sd_2015_1_e0_...  142, 489, 365, 266
#
#    faces_found
# 0            1
# 1            1
# 2            1

# %%
# Group data. Number of itentities
face_groups = faces.groupby('subject_id')
len(face_groups.groups.keys())
# Out:
# 64

# %%
# extract out one group as a test
id_MotM = face_groups.get_group('MotM')
id_MotM.head(3)
# Out:
#   subject_id  image_sequence_number gender  age lighting view cropped  \
# 0       MotM                   1984      m   21        i   fr      nc
# 5       MotM                   1995      m   21        o   fr      nc
# 8       MotM                   1994      m   21        i   fr      nc
#
#   facial_emotion  year  part occlusion image_filters level_of_difficulty  \
# 0             sd  2015     1        e0            Gn                   e
# 5             no  2015     1        e0            Gs                   e
# 8             hp  2015     1        en            nl                   e
#
#                                           image_path       face_location  \
# 0  ./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_...  171, 379, 439, 111
# 5  ./images/MotM_01995_m_21_o_fr_nc_no_2015_1_e0_...  142, 409, 409, 141
# 8  ./images/MotM_01994_m_21_i_fr_nc_hp_2015_1_en_...  134, 455, 455, 134
#
#    faces_found
# 0            1
# 5            1
# 8            1

# %%
# test template generation (biometric enrollment)
image_path = id_MotM['image_path'][0]
location = id_MotM['face_location'][0].split(", ")
template = matcher.create_template(image_path, location)
print(type(template), type(template[0]), type(template[0][0]), "\n", template)
# Out:
# <class 'list'> <class 'numpy.ndarray'> <class 'numpy.float64'>
#  [array([-1.51017696e-01,  8.16482008e-02,  7.12076873e-02, -5.81135508e-04,
#        -1.11955918e-01, -1.43141076e-02, -6.43797517e-02, -1.23610966e-01,
#         1.56638816e-01, -7.63088167e-02,  2.06025094e-01,  5.99477105e-02,
#        -2.33586609e-01, -7.22645596e-02,  8.12688321e-02,  9.96994972e-02,
#        -1.52423099e-01, -1.57981887e-01, -6.77747577e-02, -4.63530719e-02,
#         3.57958674e-02, -9.70868841e-02,  3.30040902e-02,  4.41798121e-02,
#        -2.08102554e-01, -3.49925071e-01, -1.23185083e-01, -1.33675978e-01,
#         2.48490497e-02, -9.97912735e-02,  1.19796190e-02,  4.34815884e-04,
#        -1.72491133e-01, -2.70583481e-03,  3.07523236e-02,  1.03466302e-01,
#         2.26588100e-02, -3.48281264e-02,  1.78748772e-01, -2.56113000e-02,
#        -1.85807079e-01,  5.16017526e-02,  3.97023112e-02,  1.68589398e-01,
#         2.03639880e-01,  7.55521432e-02,  9.00853127e-02, -5.27126193e-02,
#         1.29495904e-01, -2.72285551e-01,  8.21383297e-02,  1.71087533e-01,
#         7.66795576e-02,  1.73031986e-02,  1.18776336e-01, -1.83287159e-01,
#         9.76869464e-03,  1.00663319e-01, -2.06585795e-01,  1.48209408e-01,
#         8.44822973e-02, -8.38094801e-02, -4.47093844e-02,  1.60220489e-02,
#         1.64926514e-01,  1.78585410e-01, -1.34032845e-01, -9.43837538e-02,
#         1.65804103e-01, -1.75635472e-01, -1.13747446e-02,  5.77936620e-02,
#        -1.73690826e-01, -2.15612844e-01, -3.18371624e-01,  3.26333195e-02,
#         4.99514759e-01,  1.74368560e-01, -1.65371209e-01, -2.47873310e-02,
#        -1.00197859e-01,  2.37708651e-02,  2.12978572e-02,  6.08859658e-02,
#        -7.75694400e-02, -1.14504524e-01, -1.12920299e-01,  7.63175786e-02,
#         2.22726688e-01,  4.89014685e-02,  2.28678621e-02,  2.14000255e-01,
#         1.42238736e-02,  5.24349436e-02, -4.08054441e-02,  7.17068836e-02,
#        -8.79051238e-02, -1.15729682e-01, -7.35731274e-02, -2.59222686e-02,
#        -5.32650054e-02, -6.02153279e-02,  2.73739249e-02,  1.13073260e-01,
#        -1.90818846e-01,  6.03940561e-02, -2.31307000e-02, -4.29049321e-02,
#        -6.55950606e-02,  1.02491096e-01, -9.39921886e-02, -2.77810842e-02,
#         1.02151096e-01, -2.67944813e-01,  2.30834439e-01,  2.59893149e-01,
#        -6.63587824e-03,  8.71838778e-02,  2.23438218e-02,  6.16672263e-02,
#         1.13399774e-02, -3.03141475e-02, -8.89010280e-02, -9.17734951e-02,
#        -7.52507374e-02, -2.73318812e-02,  1.33560598e-02,  2.38916874e-02])]

# %%
# We should be able to create a dictionary referencing the index in the dataframe 
# to the biometric template to be used for match. We can reference the data frame to 
# know the identity of the person in the face
enrollment_list = []
for index, row in faces.iterrows():
     enrollment_list.append([index, (row['image_path'], row['face_location'].split(", "))])
enrollment_list[2]
# Out:
# [2,
#  ('./images/MosK_01975_m_20_o_nf_nc_sd_2015_1_e0_Gs_e.jpg',
#   ['142', '489', '365', '266'])]

# %%
# Now can pass this in as an argument to enroll all items and store in a dict
enrollments = matcher.enroll_batch(enrollment_list)
# Out:
# Enrolled... 0
# Enrolled... 100
# Enrolled... 200
# Enrolled... 300
# Enrolled... 400
# Enrolled... 500
# Enrolled... 600
# Enrolled... 700
# Enrolled... 800
# Enrolled... 900
# Enrolled... 1000
# Enrolled... 1100
# Enrolled... 1200
# Enrolled... 1300
# Enrolled... 1400
# Enrolled... 1500
# Enrolled... 1600
# Enrolled... 1700
# Enrolled... 1800
# Enrolled... 1900
# Finished enrolling 1961 in 55 seconds

# %% [markdown]
# ## Part 3 - matching to generate scores
# #### Unfortunately this algorithm does not generate a matching score out of the box. However we can tune a tolerance setting which will allow us to generate a score by attempting a match until the face_recognition module switch the result from True to False
# #### Since mated pairs are more likely to match, we should start the process from 1.0 and work downwards. For dissimilar pairs we should start at 0.0 and work upwards

# %%
# Dissimilar pairs
print(faces['subject_id'][0], faces['subject_id'][1])
print(matcher.single_match(enrollments[0], enrollments[1], threshold=0.24),
      matcher.single_match(enrollments[0], enrollments[1], threshold=0.23))
print(faces['image_path'][0], faces['image_path'][1])
# Out:
# MotM PetK
# [False] [True]
# ./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_Gn_e.jpg ./images/PetK_02257_m_20_i_nf_nc_no_2015_1_e0_Ps_e.jpg

# %% [markdown]
# ##### From trial and error we can see these images match around a score of 0.23
# ##### and we know it is a different person from the ground truth
# <p float="left">
#   <img style="display: inline;" src="./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_Gn_e.jpg" width="200" />
#   <img style="display: inline;" src="./images/PetK_02257_m_20_i_nf_nc_no_2015_1_e0_Ps_e.jpg" width="200" />
# </p>

# %%
# Similar pairs 
print(faces['subject_id'][0], faces['subject_id'][8])
print(matcher.single_match(enrollments[0], enrollments[8], threshold=0.60),
      matcher.single_match(enrollments[0], enrollments[8], threshold=0.59))
print(faces['image_path'][0], faces['image_path'][8])
# Out:
# MotM MotM
# [False] [True]
# ./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_Gn_e.jpg ./images/MotM_01994_m_21_i_fr_nc_hp_2015_1_en_nl_e.jpg

# %% [markdown]
# ##### From trial and error we can see these images match around a score of 0.59
# ##### and we know it is the same person from the ground truth
# <p float="left">
#   <img style="display: inline;" src="./images/MotM_01984_m_21_i_fr_nc_sd_2015_1_e0_Gn_e.jpg" width="200" />
#   <img style="display: inline;" src="./images/MotM_01994_m_21_i_fr_nc_hp_2015_1_en_nl_e.jpg" width="200" />
# </p>

# %%
# Matching a non-mated pair
matcher.generate_score(enrollments[0], enrollments[1], mate=False, logging=True, new_threshold=False)
# Out:
# testing threshold... 0.00
# testing threshold... 0.01
# testing threshold... 0.02
# testing threshold... 0.03
# testing threshold... 0.04
# testing threshold... 0.05
# testing threshold... 0.06
# testing threshold... 0.07
# testing threshold... 0.08
# testing threshold... 0.09
# testing threshold... 0.10
# testing threshold... 0.11
# testing threshold... 0.12
# testing threshold... 0.13
# testing threshold... 0.14
# testing threshold... 0.15
# testing threshold... 0.16
# testing threshold... 0.17
# testing threshold... 0.18
# testing threshold... 0.19
# testing threshold... 0.20
# testing threshold... 0.21
# testing threshold... 0.22
# testing threshold... 0.23
# testing threshold... 0.24
# '0.24'

# %%
# Matching a mated pair
matcher.generate_score(enrollments[0], enrollments[8], mate=True, logging=True, new_threshold=False)
# Out:
# testing threshold... 1.00
# testing threshold... 0.99
# testing threshold... 0.98
# testing threshold... 0.97
# testing threshold... 0.96
# testing threshold... 0.95
# testing threshold... 0.94
# testing threshold... 0.93
# testing threshold... 0.92
# testing threshold... 0.91
# testing threshold... 0.90
# testing threshold... 0.89
# testing threshold... 0.88
# testing threshold... 0.87
# testing threshold... 0.86
# testing threshold... 0.85
# testing threshold... 0.84
# testing threshold... 0.83
# testing threshold... 0.82
# testing threshold... 0.81
# testing threshold... 0.80
# testing threshold... 0.79
# testing threshold... 0.78
# testing threshold... 0.77
# testing threshold... 0.76
# testing threshold... 0.75
# testing threshold... 0.74
# testing threshold... 0.73
# testing threshold... 0.72
# testing threshold... 0.71
# testing threshold... 0.70
# testing threshold... 0.69
# testing threshold... 0.68
# testing threshold... 0.67
# testing threshold... 0.66
# testing threshold... 0.65
# testing threshold... 0.64
# testing threshold... 0.63
# testing threshold... 0.62
# testing threshold... 0.61
# testing threshold... 0.60
# testing threshold... 0.59
# '0.59'

# %%
# Now we can generate a CSV file for matches of mates and non-mates
# It should look like
# subject_id_1, subject_id_2, score
# Get the unique groups as batches of mated images
group_keys = faces.subject_id.unique
pairs = []
# Loop over each group
for group in group_keys():
    # Extract the data per group
    group_data = faces[faces['subject_id'] == group]
    # Get all indexes to loop over them    
    indexes = group_data.index.values.tolist()
    for face_num in indexes:
        for other_face_num in indexes:
            if(face_num != other_face_num): # Only match pairs that aren't the same image
                pairs.append([face_num, other_face_num])

print(pairs[0], pairs[1], pairs[2])
# Out:
# [0, 5] [0, 8] [0, 50]

# %%
# Now there is a list of tuple of image pairs to match where we can be assured they are mated pairs
matcher.cross_match_pairs(enrollments, pairs, 'mates_matched.csv')
# Out:
# 0 matches completed
# 5000 matches completed
# 10000 matches completed
# 15000 matches completed
# 20000 matches completed
# 25000 matches completed
# 30000 matches completed
# 35000 matches completed
# 40000 matches completed
# 45000 matches completed
# 50000 matches completed
# 55000 matches completed
# 60000 matches completed
# 65000 matches completed
# 70000 matches completed
# 75000 matches completed
# 80000 matches completed
# 85000 matches completed
# 90000 matches completed
# 95000 matches completed
# 100000 matches completed
# 105000 matches completed
# 110000 matches completed
# 115000 matches completed
# 120000 matches completed
# 125000 matches completed
# 130000 matches completed
# Finished matching pairs in 104 seconds

# %%
# Matching imposters takes the identities that arent the same person
imposters = []
# Loop over each group
for group in group_keys():
    # Extract the data per group
    group_data = faces[faces['subject_id'] == group]
    imposter_data = faces[faces['subject_id'] != group]
    # Get all indexes to loop over them 
    indexes = group_data.index.values.tolist()
    indexes_imposters = imposter_data.index.values.tolist()
    # print(indexes)
    for face_num in indexes:
        # print(face_num)
        for imposter in indexes_imposters:
            imposters.append([face_num, imposter])

print(imposters[0], imposters[1], imposters[2], imposters[3], imposters[4])
# Out:
# [0, 1] [0, 2] [0, 3] [0, 4] [0, 6]

# %%
matcher.cross_match_pairs(enrollments, imposters, 'imposters_matched.csv')
# Out:
# 0 matches completed
# 5000 matches completed
# 10000 matches completed
# 15000 matches completed
# 20000 matches completed
# 25000 matches completed
# 30000 matches completed
# 35000 matches completed
# 40000 matches completed
# 45000 matches completed
# 50000 matches completed
# 55000 matches completed
# 60000 matches completed
# 65000 matches completed
# 70000 matches completed
# 75000 matches completed
# 80000 matches completed
# 85000 matches completed
# 90000 matches completed
# 95000 matches completed
# 100000 matches completed
# 105000 matches completed
# 110000 matches completed
# 115000 matches completed
# 120000 matches completed
# 125000 matches completed
# 130000 matches completed
# 135000 matches completed
# 140000 matches completed
# 145000 matches completed
# 150000 matches completed
# 155000 matches completed
# 160000 matches completed
# 165000 matches completed
# 170000 matches completed
# 175000 matches completed
# 180000 matches completed
# 185000 matches completed
# 190000 matches completed
# 195000 matches completed
# 200000 matches completed
# 205000 matches completed
# 210000 matches completed
# 215000 matches completed
# 220000 matches completed
# 225000 matches completed
# 230000 matches completed
# 235000 matches completed
# 240000 matches completed
# 245000 matches completed
# 250000 matches completed
# 255000 matches completed
# 260000 matches completed
# 265000 matches completed
# 270000 matches completed
# 275000 matches completed
# 280000 matches completed
# 285000 matches completed
# 290000 matches completed
# 295000 matches completed
# 300000 matches completed
# 305000 matches completed
# 310000 matches completed
# 315000 matches completed
# 320000 matches completed
# 325000 matches completed
# 330000 matches completed
# 335000 matches completed
# 340000 matches completed
# 345000 matches completed
# 350000 matches completed
# 355000 matches completed
# 360000 matches completed
# 365000 matches completed
# 370000 matches completed
# 375000 matches completed
# 380000 matches completed
# 385000 matches completed
# 390000 matches completed
# 395000 matches completed
# 400000 matches completed
# 405000 matches completed
# 410000 matches completed
# 415000 matches completed
# 420000 matches completed
# 425000 matches completed
# 430000 matches completed
# 435000 matches completed
# 440000 matches completed
# 445000 matches completed
# 450000 matches completed
# 455000 matches completed
# 460000 matches completed
# 465000 matches completed
# 470000 matches completed
# 475000 matches completed
# 480000 matches completed
# 485000 matches completed
# 490000 matches completed
# 495000 matches completed
# 500000 matches completed
# 505000 matches completed
# 510000 matches completed
# 515000 matches completed
# 520000 matches completed
# 525000 matches completed
# 530000 matches completed
# 535000 matches completed
# 540000 matches completed
# 545000 matches completed
# 550000 matches completed
# 555000 matches completed
# 560000 matches completed
# 565000 matches completed
# 570000 matches completed
# 575000 matches completed
# 580000 matches completed
# 585000 matches completed
# 590000 matches completed
# 595000 matches completed
# 600000 matches completed
# 605000 matches completed
# 610000 matches completed
# 615000 matches completed
# 620000 matches completed
# 625000 matches completed
# 630000 matches completed
# 635000 matches completed
# 640000 matches completed
# 645000 matches completed
# 650000 matches completed
# 655000 matches completed
# 660000 matches completed
# 665000 matches completed
# 670000 matches completed
# 675000 matches completed
# 680000 matches completed
# 685000 matches completed
# 690000 matches completed
# 695000 matches completed
# 700000 matches completed
# 705000 matches completed
# 710000 matches completed
# 715000 matches completed
# 720000 matches completed
# 725000 matches completed
# 730000 matches completed
# 735000 matches completed
# 740000 matches completed
# 745000 matches completed
# 750000 matches completed
# 755000 matches completed
# 760000 matches completed
# 765000 matches completed
# 770000 matches completed
# 775000 matches completed
# 780000 matches completed
# 785000 matches completed
# 790000 matches completed
# 795000 matches completed
# 800000 matches completed
# 805000 matches completed
# 810000 matches completed
# 815000 matches completed
# 820000 matches completed
# 825000 matches completed
# 830000 matches completed
# 835000 matches completed
# 840000 matches completed
# 845000 matches completed
# 850000 matches completed
# 855000 matches completed
# 860000 matches completed
# 865000 matches completed
# 870000 matches completed
# 875000 matches completed
# 880000 matches completed
# 885000 matches completed
# 890000 matches completed
# 895000 matches completed
# 900000 matches completed
# 905000 matches completed
# 910000 matches completed
# 915000 matches completed
# 920000 matches completed
# 925000 matches completed
# 930000 matches completed
# 935000 matches completed
# 940000 matches completed
# 945000 matches completed
# 950000 matches completed
# 955000 matches completed
# 960000 matches completed
# 965000 matches completed
# 970000 matches completed
# 975000 matches completed
# 980000 matches completed
# 985000 matches completed
# 990000 matches completed
# 995000 matches completed
# 1000000 matches completed
# 1005000 matches completed
# 1010000 matches completed
# 1015000 matches completed
# 1020000 matches completed
# 1025000 matches completed
# 1030000 matches completed
# 1035000 matches completed
# 1040000 matches completed
# 1045000 matches completed
# 1050000 matches completed
# 1055000 matches completed
# 1060000 matches completed
# 1065000 matches completed
# 1070000 matches completed
# 1075000 matches completed
# 1080000 matches completed
# 1085000 matches completed
# 1090000 matches completed
# 1095000 matches completed
# 1100000 matches completed
# 1105000 matches completed
# 1110000 matches completed
# 1115000 matches completed
# 1120000 matches completed
# 1125000 matches completed
# 1130000 matches completed
# 1135000 matches completed
# 1140000 matches completed
# 1145000 matches completed
# 1150000 matches completed
# 1155000 matches completed
# 1160000 matches completed
# 1165000 matches completed
# 1170000 matches completed
# 1175000 matches completed
# 1180000 matches completed
# 1185000 matches completed
# 1190000 matches completed
# 1195000 matches completed
# 1200000 matches completed
# 1205000 matches completed
# 1210000 matches completed
# 1215000 matches completed
# 1220000 matches completed
# 1225000 matches completed
# 1230000 matches completed
# 1235000 matches completed
# 1240000 matches completed
# 1245000 matches completed
# 1250000 matches completed
# 1255000 matches completed
# 1260000 matches completed
# 1265000 matches completed
# 1270000 matches completed
# 1275000 matches completed
# 1280000 matches completed
# 1285000 matches completed
# 1290000 matches completed
# 1295000 matches completed
# 1300000 matches completed
# 1305000 matches completed
# 1310000 matches completed
# 1315000 matches completed
# 1320000 matches completed
# 1325000 matches completed
# 1330000 matches completed
# 1335000 matches completed
# 1340000 matches completed
# 1345000 matches completed
# 1350000 matches completed
# 1355000 matches completed
# 1360000 matches completed
# 1365000 matches completed
# 1370000 matches completed
# 1375000 matches completed
# 1380000 matches completed
# 1385000 matches completed
# 1390000 matches completed
# 1395000 matches completed
# 1400000 matches completed
# 1405000 matches completed
# 1410000 matches completed
# 1415000 matches completed
# 1420000 matches completed
# 1425000 matches completed
# 1430000 matches completed
# 1435000 matches completed
# 1440000 matches completed
# 1445000 matches completed
# 1450000 matches completed
# 1455000 matches completed
# 1460000 matches completed
# 1465000 matches completed
# 1470000 matches completed
# 1475000 matches completed
# 1480000 matches completed
# 1485000 matches completed
# 1490000 matches completed
# 1495000 matches completed
# 1500000 matches completed
# 1505000 matches completed
# 1510000 matches completed
# 1515000 matches completed
# 1520000 matches completed
# 1525000 matches completed
# 1530000 matches completed
# 1535000 matches completed
# 1540000 matches completed
# 1545000 matches completed
# 1550000 matches completed
# 1555000 matches completed
# 1560000 matches completed
# 1565000 matches completed
# 1570000 matches completed
# 1575000 matches completed
# 1580000 matches completed
# 1585000 matches completed
# 1590000 matches completed
# 1595000 matches completed
# 1600000 matches completed
# 1605000 matches completed
# 1610000 matches completed
# 1615000 matches completed
# 1620000 matches completed
# 1625000 matches completed
# 1630000 matches completed
# 1635000 matches completed
# 1640000 matches completed
# 1645000 matches completed
# 1650000 matches completed
# 1655000 matches completed
# 1660000 matches completed
# 1665000 matches completed
# 1670000 matches completed
# 1675000 matches completed
# 1680000 matches completed
# 1685000 matches completed
# 1690000 matches completed
# 1695000 matches completed
# 1700000 matches completed
# 1705000 matches completed
# 1710000 matches completed
# 1715000 matches completed
# 1720000 matches completed
# 1725000 matches completed
# 1730000 matches completed
# 1735000 matches completed
# 1740000 matches completed
# 1745000 matches completed
# 1750000 matches completed
# 1755000 matches completed
# 1760000 matches completed
# 1765000 matches completed
# 1770000 matches completed
# 1775000 matches completed
# 1780000 matches completed
# 1785000 matches completed
# 1790000 matches completed
# 1795000 matches completed
# 1800000 matches completed
# 1805000 matches completed
# 1810000 matches completed
# 1815000 matches completed
# 1820000 matches completed
# 1825000 matches completed
# 1830000 matches completed
# 1835000 matches completed
# 1840000 matches completed
# 1845000 matches completed
# 1850000 matches completed
# 1855000 matches completed
# 1860000 matches completed
# 1865000 matches completed
# 1870000 matches completed
# 1875000 matches completed
# 1880000 matches completed
# 1885000 matches completed
# 1890000 matches completed
# 1895000 matches completed
# 1900000 matches completed
# 1905000 matches completed
# 1910000 matches completed
# 1915000 matches completed
# 1920000 matches completed
# 1925000 matches completed
# 1930000 matches completed
# 1935000 matches completed
# 1940000 matches completed
# 1945000 matches completed
# 1950000 matches completed
# 1955000 matches completed
# 1960000 matches completed
# 1965000 matches completed
# 1970000 matches completed
# 1975000 matches completed
# 1980000 matches completed
# 1985000 matches completed
# 1990000 matches completed
# 1995000 matches completed
# 2000000 matches completed
# 2005000 matches completed
# 2010000 matches completed
# 2015000 matches completed
# 2020000 matches completed
# 2025000 matches completed
# 2030000 matches completed
# 2035000 matches completed
# 2040000 matches completed
# 2045000 matches completed
# 2050000 matches completed
# 2055000 matches completed
# 2060000 matches completed
# 2065000 matches completed
# 2070000 matches completed
# 2075000 matches completed
# 2080000 matches completed
# 2085000 matches completed
# 2090000 matches completed
# 2095000 matches completed
# 2100000 matches completed
# 2105000 matches completed
# 2110000 matches completed
# 2115000 matches completed
# 2120000 matches completed
# 2125000 matches completed
# 2130000 matches completed
# 2135000 matches completed
# 2140000 matches completed
# 2145000 matches completed
# 2150000 matches completed
# 2155000 matches completed
# 2160000 matches completed
# 2165000 matches completed
# 2170000 matches completed
# 2175000 matches completed
# 2180000 matches completed
# 2185000 matches completed
# 2190000 matches completed
# 2195000 matches completed
# 2200000 matches completed
# 2205000 matches completed
# 2210000 matches completed
# 2215000 matches completed
# 2220000 matches completed
# 2225000 matches completed
# 2230000 matches completed
# 2235000 matches completed
# 2240000 matches completed
# 2245000 matches completed
# 2250000 matches completed
# 2255000 matches completed
# 2260000 matches completed
# 2265000 matches completed
# 2270000 matches completed
# 2275000 matches completed
# 2280000 matches completed
# 2285000 matches completed
# 2290000 matches completed
# 2295000 matches completed
# 2300000 matches completed
# 2305000 matches completed
# 2310000 matches completed
# 2315000 matches completed
# 2320000 matches completed
# 2325000 matches completed
# 2330000 matches completed
# 2335000 matches completed
# 2340000 matches completed
# 2345000 matches completed
# 2350000 matches completed
# 2355000 matches completed
# 2360000 matches completed
# 2365000 matches completed
# 2370000 matches completed
# 2375000 matches completed
# 2380000 matches completed
# 2385000 matches completed
# 2390000 matches completed
# 2395000 matches completed
# 2400000 matches completed
# 2405000 matches completed
# 2410000 matches completed
# 2415000 matches completed
# 2420000 matches completed
# 2425000 matches completed
# 2430000 matches completed
# 2435000 matches completed
# 2440000 matches completed
# 2445000 matches completed
# 2450000 matches completed
# 2455000 matches completed
# 2460000 matches completed
# 2465000 matches completed
# 2470000 matches completed
# 2475000 matches completed
# 2480000 matches completed
# 2485000 matches completed
# 2490000 matches completed
# 2495000 matches completed
# 2500000 matches completed
# 2505000 matches completed
# 2510000 matches completed
# 2515000 matches completed
# 2520000 matches completed
# 2525000 matches completed
# 2530000 matches completed
# 2535000 matches completed
# 2540000 matches completed
# 2545000 matches completed
# 2550000 matches completed
# 2555000 matches completed
# 2560000 matches completed
# 2565000 matches completed
# 2570000 matches completed
# 2575000 matches completed
# 2580000 matches completed
# 2585000 matches completed
# 2590000 matches completed
# 2595000 matches completed
# 2600000 matches completed
# 2605000 matches completed
# 2610000 matches completed
# 2615000 matches completed
# 2620000 matches completed
# 2625000 matches completed
# 2630000 matches completed
# 2635000 matches completed
# 2640000 matches completed
# 2645000 matches completed
# 2650000 matches completed
# 2655000 matches completed
# 2660000 matches completed
# 2665000 matches completed
# 2670000 matches completed
# 2675000 matches completed
# 2680000 matches completed
# 2685000 matches completed
# 2690000 matches completed
# 2695000 matches completed
# 2700000 matches completed
# 2705000 matches completed
# 2710000 matches completed
# 2715000 matches completed
# 2720000 matches completed
# 2725000 matches completed
# 2730000 matches completed
# 2735000 matches completed
# 2740000 matches completed
# 2745000 matches completed
# 2750000 matches completed
# 2755000 matches completed
# 2760000 matches completed
# 2765000 matches completed
# 2770000 matches completed
# 2775000 matches completed
# 2780000 matches completed
# 2785000 matches completed
# 2790000 matches completed
# 2795000 matches completed
# 2800000 matches completed
# 2805000 matches completed
# 2810000 matches completed
# 2815000 matches completed
# 2820000 matches completed
# 2825000 matches completed
# 2830000 matches completed
# 2835000 matches completed
# 2840000 matches completed
# 2845000 matches completed
# 2850000 matches completed
# 2855000 matches completed
# 2860000 matches completed
# 2865000 matches completed
# 2870000 matches completed
# 2875000 matches completed
# 2880000 matches completed
# 2885000 matches completed
# 2890000 matches completed
# 2895000 matches completed
# 2900000 matches completed
# 2905000 matches completed
# 2910000 matches completed
# 2915000 matches completed
# 2920000 matches completed
# 2925000 matches completed
# 2930000 matches completed
# 2935000 matches completed
# 2940000 matches completed
# 2945000 matches completed
# 2950000 matches completed
# 2955000 matches completed
# 2960000 matches completed
# 2965000 matches completed
# 2970000 matches completed
# 2975000 matches completed
# 2980000 matches completed
# 2985000 matches completed
# 2990000 matches completed
# 2995000 matches completed
# 3000000 matches completed
# 3005000 matches completed
# 3010000 matches completed
# 3015000 matches completed
# 3020000 matches completed
# 3025000 matches completed
# 3030000 matches completed
# 3035000 matches completed
# 3040000 matches completed
# 3045000 matches completed
# 3050000 matches completed
# 3055000 matches completed
# 3060000 matches completed
# 3065000 matches completed
# 3070000 matches completed
# 3075000 matches completed
# 3080000 matches completed
# 3085000 matches completed
# 3090000 matches completed
# 3095000 matches completed
# 3100000 matches completed
# 3105000 matches completed
# 3110000 matches completed
# 3115000 matches completed
# 3120000 matches completed
# 3125000 matches completed
# 3130000 matches completed
# 3135000 matches completed
# 3140000 matches completed
# 3145000 matches completed
# 3150000 matches completed
# 3155000 matches completed
# 3160000 matches completed
# 3165000 matches completed
# 3170000 matches completed
# 3175000 matches completed
# 3180000 matches completed
# 3185000 matches completed
# 3190000 matches completed
# 3195000 matches completed
# 3200000 matches completed
# 3205000 matches completed
# 3210000 matches completed
# 3215000 matches completed
# 3220000 matches completed
# 3225000 matches completed
# 3230000 matches completed
# 3235000 matches completed
# 3240000 matches completed
# 3245000 matches completed
# 3250000 matches completed
# 3255000 matches completed
# 3260000 matches completed
# 3265000 matches completed
# 3270000 matches completed
# 3275000 matches completed
# 3280000 matches completed
# 3285000 matches completed
# 3290000 matches completed
# 3295000 matches completed
# 3300000 matches completed
# 3305000 matches completed
# 3310000 matches completed
# 3315000 matches completed
# 3320000 matches completed
# 3325000 matches completed
# 3330000 matches completed
# 3335000 matches completed
# 3340000 matches completed
# 3345000 matches completed
# 3350000 matches completed
# 3355000 matches completed
# 3360000 matches completed
# 3365000 matches completed
# 3370000 matches completed
# 3375000 matches completed
# 3380000 matches completed
# 3385000 matches completed
# 3390000 matches completed
# 3395000 matches completed
# 3400000 matches completed
# 3405000 matches completed
# 3410000 matches completed
# 3415000 matches completed
# 3420000 matches completed
# 3425000 matches completed
# 3430000 matches completed
# 3435000 matches completed
# 3440000 matches completed
# 3445000 matches completed
# 3450000 matches completed
# 3455000 matches completed
# 3460000 matches completed
# 3465000 matches completed
# 3470000 matches completed
# 3475000 matches completed
# 3480000 matches completed
# 3485000 matches completed
# 3490000 matches completed
# 3495000 matches completed
# 3500000 matches completed
# 3505000 matches completed
# 3510000 matches completed
# 3515000 matches completed
# 3520000 matches completed
# 3525000 matches completed
# 3530000 matches completed
# 3535000 matches completed
# 3540000 matches completed
# 3545000 matches completed
# 3550000 matches completed
# 3555000 matches completed
# 3560000 matches completed
# 3565000 matches completed
# 3570000 matches completed
# 3575000 matches completed
# 3580000 matches completed
# 3585000 matches completed
# 3590000 matches completed
# 3595000 matches completed
# 3600000 matches completed
# 3605000 matches completed
# 3610000 matches completed
# 3615000 matches completed
# 3620000 matches completed
# 3625000 matches completed
# 3630000 matches completed
# 3635000 matches completed
# 3640000 matches completed
# 3645000 matches completed
# 3650000 matches completed
# 3655000 matches completed
# 3660000 matches completed
# 3665000 matches completed
# 3670000 matches completed
# 3675000 matches completed
# 3680000 matches completed
# 3685000 matches completed
# 3690000 matches completed
# 3695000 matches completed
# 3700000 matches completed
# 3705000 matches completed
# 3710000 matches completed
# Finished matching pairs in 4585 seconds

# %% [markdown]
# ##### Please refer to part 4 for a brief analysis of scores generated from this dataset...
